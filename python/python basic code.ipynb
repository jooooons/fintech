# %%
#String
txt1 = 'A tale that was not right'
# 'ale' 이 출력..
txt1[3:6]
# 'A tale' 출력
txt1[:6]
# 'not' 출력
txt1[-9:-6]
# txt1을 소문자 전환
txt1.lower()
# txt1을 대문자 전환
txt1.upper()
# 'o'가 몇 개 존재하는가?
txt1.count('o')
# 'o'가 몇 번 인덱스에 존재하는가?
txt1.find('o')
# txt1의 길이는 어떻게 되는가?
len(txt1)
# space를 기준으로 나누어서 List에 담으세요..
txt1.split(' ')
# 'tale'을 'story'로 바꾸세요..
txt1.replace('tale', 'story')
# txt1 안에 'right'가 존재하는지 확인
'right' in txt1

# %%
#List
sol = ['태양','수성','금성','지구','화성','목성','지구']
sol1 = ['토성','천황성','해왕성']
planet = '지구'

# 1. sol에서 ['수성','금성']을 출력
sol[1:3]
# 2. sol에서 '지구' 위치 인덱스 출력
sol.index('지구')
# 3. sol에서 '화성'을 '해왕성'으로 수정
sol[4]='해왕성'
# 4. '수성'자리에 '명왕성' 삽입
sol.insert(1,'명왕성')
# 5. '토성'을 맨 끝에 삽입
sol.append('토성')
# 6. 맨 끝 요소를 삭제하고 리턴
sol.pop()
# 7. '금성'을 제거
sol.remove('금성')
# 8. 1번 인덱스에서 3번 인덱스까지 삭제
del sol[1:4]
# 9. 인덱스 2번 요소 삭제
sol.pop(2)
# 10. sol과 sol1을 합치세요
sol.extend(sol1)
# 11. 내림차순 정렬
sorted(sol, reverse=True)
# 12. 오름차순 정렬
sorted(sol)
# 13. '만리장성'이 있는지 확인
'만리장성' in sol
# 14. so1을 3번 반복하세요
sol1 * 3
# 15. 길이를 출력하세요
len(sol)
# 16. '지구'가 몇 개 포함되어있는지 확인.
sol.count('지구')
# 17. 모든 원소를 지우세요.
sol.clear()
# 18. sol리스트를 삭제하세요..
del(sol)

# %%
#Tuple
myTuple = ('tuple', (1,2,3) , [4,5,6,7,8] ,'7', '8', '9')

# 'tuple'을 출력하세요
myTuple[0]
# 3을 출력하세요
myTuple[1][2]
# 4,5를 출력하세요
myTuple[2][0],myTuple[2][1]
# [4,5,6]을 출력하세요
myTuple[2][0:3]
# tuple의 길이를 리턴하세요 ( 요소의 갯수가 몇 개인지 )
len(myTuple)
# '7'이 있는지 확인하세요
'7' in myTuple
# '7'의 인덱스를 출력하세요.
myTuple.index('7')
# '7'이 몇 개 있는지 확인하세요
myTuple.count('7')
# 인데스 2번를 출력하세요
myTuple[2]
# 인데스 2번에서 최대값을 출력하세요
max(myTuple[2])
# 인데스 2번에서 최소값을 출력하세요
min(myTuple[2])
# 인데스 2번에서 총합을 출력하세요
sum(myTuple[2])
# 인데스 2번에서 평균을 출력하세요
sum(myTuple[2])/len(myTuple[2]) 
# 인데스 2번를 내림차순 정렬해서 출력하세요.
print(sorted(myTuple[2],reverse = True))

# %%
#Set

# 원소가 없는 set인 s를 만드세요
s = set()
# s에 원소 'sky'와 'earth'를 추가하세요
s = {'sky', 'earth'}
# s에 1,2 두 원소를 추가하세요
s.update({1,2})
# s에서 'sky'를 삭제하세요
s.remove('sky')

A = {1,2,3,4,5,6}
B = {1,2,3,7,8,9}
C = {1,2,3}
# 두 집합의 합집합을 출력
A.union(B)
# 두 집합의 교집합을 출력
A.intersection(B)
# A의 B에 대한 차집합
A.difference(B)
# 대칭차집합
A.union(B).difference(A.intersection(B))
A.symmetric_difference(B)
# C가 A의 부분집합인지 확인
C.issubset(A)
# A가 C를 포함하는지 확인
A.issuperset(C)


# 집합 B의 길이를 출력
len(B)
# 집합 B의 최대값 출력
max(B)
# 집합 B의 최소값 출력
min(B)
# 집합 B의 합을 출력
sum(B)
# 집합 B의 평균출력
sum(B)/len(B) 
# 집합 B의 내림차순 출력
sorted(B, reverse=True)
# 집합 B에 5가 포함되어 있는지 확인
5 in B

# %%
#Dictionary

# 'mydict'라는 딕셔너리를 만드세요.
mydict = {}
# 'red':4, 'blue':3, 'green':1 세 요소를 추가하세요.
mydict = {'red':4, 'blue':3, 'green':1}
# key에 'blue'가 있는지 확인하세요.
'blue' in mydict
# mydict의 길이를 출력하세요.
len(mydict)
# 'red'의 값을 출력하세요.
#list(mydict.keys())[0]
mydict['red']
# 'red'의 값을 10으로 수정하세요.
mydict['red'] = 10
# key값만 출력하세요
mydict.keys()
# value값만 출력하세요
mydict.values()
# key와 value를 튜플로 출력하세요.
mydict.items()
# (key기준으로 정렬하세요.)
sorted(mydict.keys())
#sorted(mydict.items, key = lambda x : x[0])
# (value기준으로 정렬하세요)
sorted(mydict.values())
#sorted(mydict.items, key = lambda x : x[1])
# key 'blue'요소를 삭제하세요
mydict.pop('blue')
# key 'pink'요소 값을 출력하되 오류가 없도록 하세요
mydict.get('pink')
# key 'pink' 값을 출력하되 없으면, value 20으로 새로이 추가하세요
mydict.setdefault('pink', 20)
# value에 20이 있는지 확인하세요.
20 in mydict.values()
# key는 'yellow'에 value는 30을 추가하세요.
mydict['yellow'] = 30
# yourdict = {'파랑':50, '빨강':70}을 합하세요..
mydict.update({'파랑':50, '빨강':70})

# %%
#If 

## 임의 정수(n)를 입력받은 후 0부터 n까지의 정수 중 짝수들의 합을 구하시오.
n = int(input())
sum = 0
for i in range(n+1):
    if i % 2:continue
    else : sum+=i
print(sum)

# names = {'mary':1520, 'tom':5214, 'park':5478, 'sams':5478} 
# 이름을 입력받은 후 names dict에 이름이 있으면 값을 출력하고, 
# 없으면 새로운 값 2000과 함께 dict에 'key':'value'로 추가 
# setdefault를 사용하지 않음.. 
names = {'mary':1520, 'tom':5214, 'park':5478, 'sams':5478} 
input_name = input()
if input_name in names:
    print(names.get(input_name))
else:
    names.update({input_name:2000})

# 학점 출력.. 점수를 입력받은 후.. 
# 90점 이상이면 "당신은 'A'학점입니다"를 출력 
# 80점 이상이면서 90점 미만이면 "당신은 'B'학점입니다"를 출력 
# 70점 이상이면서 80점 미만이면 "당신은 'C'학점입니다"를 출력 
# 70점 미만이면 "당신은 D학점입니다"를 출력
score = int(input())
if score >= 90 : print("당신은 'A'학점입니다")
elif score >= 80 : print("당신은 'B'학점입니다")
elif score >= 70 : print("당신은 'C'학점입니다")
else : print("당신은 D학점입니다")

# %%
# password = 1234
# input_pass = int(input("패스워드 입력 : "))
# if input_pass == password:
#     print("환영합니다")
# else : print("비밀번호가 틀립니다")


# num = int(input("임의의 정수 입력"))
# if num%2 :
#     print("홀수입니다")
# else: print("짝수입니다")


# id = input("주민번호를 입력하세요 ")
# if int(id[:2]) > 22 : age = 2022 - (int(id[:2]) + 1900) + 1
# else : age = 22 - int(id[:2]) + 1
# if id[7] == '1' or id[7] == '3' : gender = "남성"
# else : gender = "여성"
# print(f"당신의 나이는 {age}이고, 성별은 {gender}입니다.")


# scores = {"Mary":85, "Sam":95, "Bob":87, "Han":77}
# nam = input("이름을 입력하세요:")
# if nam in scores :
#     if scores[nam] >= 80 : print("합격입니다.")
#     else : print("불합격입니다.")
# else : scores.setdefault(nam,0)


# mine = input("가위,바위,보 중에 입력")
# yours = input("가위,바위,보 중에 입력")
# if mine == yours : print("비겼습니다.")
# elif mine == "가위":
#     if yours == "바위" : print("내가 졌습니다.")
#     else : print("내가 이겼습니다.")
# elif mine == "바위" :
#     if yours == "가위" : print("내가 이겼습니다.")
#     else : print("내가 졌습니다.")
# elif mine == "보":
#     if yours == "가위" : print("내가 졌습니다.")
#     else : print("내가 이겼습니다")


# age = int(input("나이를 입력하세요"))
# if age >= 50 : print("중년이시군요.")
# elif age >= 20 : print("젊으시군요")
# else : print("어리시군요")

# %%
#For 

# text = 'python is fun' # text의 character를 모음만 대문자로 전환해서 출력하세요. 참고) 영어모음 = ‘aeiou’ 
text = 'python is fun'
for i in text:
    if i in 'aeiou':
        text = text.replace(i, i.upper())
print(text)

# 위의 text의 문자를 index와 함께 출력하시오. 
for i in range(len(text)):
    print(i, text[i])

# 1~20까지 수에서 짝수만 리스트에 담으세요. 
# => for문과 while문, list comprehension을 각각 활용 
list1 = []
j = 1
for i in range(1,21):
    if not i % 2:
        list1.append(i)
        
list2 = []
while j <= 20 :
    if not j%2:
        list2.append(j)
    j += 1
    
list3 = [k for k in range(1,21) if not k%2]
    

# 1~10까지 정수를 출력하는 while문에서 continue와 break를 이용해서 3,4,5,6만 출력하도록 하시오. 
i = 0
while 1:
    i += 1
    if i > 10 : break
    if i < 3 or i>6: continue
    else: print(i)
    
# x = ['a','b','c','d','e'], y = ['가','나','다','라','마'] 두 리스트의 원소들의 모든 조합을 아래와 같이 출력하시오. => 
# [('a','가'), ('a','나'), ('a', '다') ... ('e','라'), ('e', '마')] 
x = ['a','b','c','d','e']
y = ['가','나','다','라','마']
list = []
for i in x:
    for j in y:
        list.append((i,j))
print(list)

# computational thinking에서 홀수인덱스만 리스트에 담으세요.. 
text = "computational thinking"
list_odd = []
for i in range(1,len(text), 2):
    list_odd.append(text[i])
print(list_odd)

# 점수를 5회 입력받은 후 평균을 출력하세요. 
scores = []
for i in range(5):
    scores.append(int(input()))
print(sum(scores)/len(scores))

# text = 'hello world'에서 각 문자를 인덱스와 함께 튜플로 묶어서 출력 
# (0, 'h'), (1, 'e') ... 
text = 'hello world'
for i in range(len(text)):
    print((i, text[i]), end=', ')

# 구구단을 출력하시오...
for i in range(2,10):
    for j in range(1,10):
        print(f"{i} * {j} = {i*j}")

# %%
# words = ['mountain', 'sea', 'sky', 'river', 'cloud', 'tree', 'lake']
# sum = 0
# for i in words:
#     if len(i) >= 4:
#         sum += len(i)
# sum


# li = []
# l1 = ['a', 'b', 'c', 'd']
# l2 = ['가', '나', '다', '라']
# for i in l1:
#     for j in l2:
#         li.append((i,j))
# li


# oddSum = 0
# evenSum = 0
# for i in range(1,21):
#     if i % 2 : oddSum += i
#     else : evenSum += i
# print(f"홀수합은 {oddSum}이고, 짝수합은 {evenSum}이다.")


# fac = int(input("양의 정수 입력하세요: "))
# ans = 1
# for i in range(1, fac+1):
#     ans *= i
# ans


# L = [70, 100, 80, 120, 130]
# MAX = L[0]
# MIN = L[0]
# for i in L:
#     if MAX < i : MAX = i
#     if MIN > i : MIN = i
# print(f"최댓값은 {MAX}, 최솟값은 {MIN}")


# for i in range(1,6):
#     print('*' * i)
# for i in range(5):
#     print((' ' * i) + '*' * (5-i) )
# for i in range(1,6):
#     print((' ' * (5-i)) + '*' * i)
# for i in range(5):
#     print('*' * (5-i))

# %%
#Function 

# 매개변수 3개를 받고, 합계, 평균, 최대값을 각각 리턴하는 함수를 만들고 실행하시오. 
def calSum(a,b,c):
    return a+b+c
def calAve(a,b,c):
    return (a+b+c)/3
def calMax(a,b,c):
    return max(a,b,c)
    
# 임의의 정수를 입력받은 후 절대값을 리턴하는 함수를 만들고 실행하시오. 
def abval():
    a = int(input())
    if a<0 : a= -a
    return a

# 임의의 정수를 입력받은 후 0부터 임의의 정수까지의 홀수 합을 리턴하는 함수를 만들고 실행하시오. 
def sumOdd():
    a = int(input())
    sum = 0
    for i in range(a+1):
        if i%2 : sum += i
    return sum

# 반지름을 입력받은 후 원의 면적을 리턴하는 함수를 구현하고 실행하시오. pi = 3.14, circle_area = (radius**2)*pi
def findArea():
    radius = float(input())
    pi = 3.14
    return (radius**2)*pi
