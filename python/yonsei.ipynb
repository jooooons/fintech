# %%
import requests
from bs4 import BeautifulSoup
url = "https://yongei.yonsei.ac.kr/yongei/course/science_course.do"
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')
tags = soup.select('#jwxe_main_content > div > div > table > tbody > tr > td:nth-child(2)')


list = []
for i in tags:
    list.append(i)
list
# Out:
# [<td valign="center" width="22.9277mm">
#  <p>
#  <span dir="ltr" lang="en-US" xml:lang="en-US"><strong>학정번호</strong></span></p>
#  </td>,
#  <td valign="center" width="22.9277mm">
#  <p>
#  <span dir="ltr" lang="en-US" xml:lang="en-US">COG3101</span></p>
#  </td>,
#  <td valign="center" width="22.9277mm">
#  <p>
#  <span dir="ltr" lang="en-US" xml:lang="en-US">COG3102</span></p>
#  </td>,
#  <td valign="center" width="22.9277mm">
#  <p>
#  <span dir="ltr" lang="en-US" xml:lang="en-US">COG3103</span></p>
#  </td>,
#  <td valign="center" width="22.9277mm">
#  <p>
#  <span dir="ltr" lang="en-US" xml:lang="en-US">COG4101</span></p>
#  </td>,
#  <td valign="center" width="22.9277mm">
#  						COG3104</td>,
#  <td valign="center" width="22.9277mm">
#  						COG3105</td>,
#  <td valign="center" width="22.9277mm">
#  <p>
#  <span dir="ltr" lang="en-US" xml:lang="en-US">FIL3102</span></p>
#  </td>,
#  <td valign="center" width="22.9277mm">
#  						FIL3107</td>,
# ...
